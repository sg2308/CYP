# %%
import geopandas as gpd

# %%
districts=gpd.read_file("C:\\Users\\GOEL\\Desktop\\MTP\\data\\maps-master\\Districts\\Census_2011\\2011_Dist.shp")

# %%
districts.shape
# Out:
# (641, 6)

# %%
districts.head(100)
# Out:
#           DISTRICT               ST_NM  ST_CEN_CD  DT_CEN_CD  censuscode  \
# 0         Adilabad      Andhra Pradesh         28          1         532
# 1             Agra       Uttar Pradesh          9         15         146
# 2        Ahmadabad             Gujarat         24          7         474
# 3       Ahmadnagar         Maharashtra         27         26         522
# 4           Aizawl             Mizoram         15          3         283
# 5            Ajmer           Rajasthan          8         21         119
# 6            Akola         Maharashtra         27          5         501
# 7        Alappuzha              Kerala         32         11         598
# 8          Aligarh       Uttar Pradesh          9         12         143
# 9        Alirajpur      Madhya Pradesh         23         48         465
# 10       Allahabad       Uttar Pradesh          9         44         175
# 11          Almora         Uttarakhand          5          9          64
# ...

# %%
type(districts.iloc[1]["geometry"])
# Out:
# shapely.geometry.polygon.Polygon

# %%
districts.iloc[83]["geometry"]

# %%
gpd.GeoSeries(districts.iloc[83]["geometry"]).to_file('bij.gpkg', 'GPKG')
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# <ipython-input-8-f128141a3eea> in <module>
# ----> 1 gpd.GeoSeries(districts.iloc[83]["geometry"]).to_file('bij.gpkg', 'GPKG')
#
# ~\Anaconda3\envs\new_mtp\lib\site-packages\geopandas\geoseries.py in to_file(self, filename, driver, **kwargs)
#     117                           index=self.index)
#     118         data.crs = self.crs
# --> 119         data.to_file(filename, driver, **kwargs)
#     120
#     121     #
#
# ~\Anaconda3\envs\new_mtp\lib\site-packages\geopandas\geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     411         """
#     412         from geopandas.io.file import to_file
# --> 413         to_file(self, filename, driver, schema, **kwargs)
#     414
#     415     def to_crs(self, crs=None, epsg=None, inplace=False):
#
# ...

# %%
for d in districts.ST_NM.unique():
    
    ax = districts[districts["ST_NM"]==d].plot(facecolor='b', figsize=(12,8))
    fig = ax.figure; fig.tight_layout()
    fig.savefig(d+'.png')
# Out:
# C:\Users\GOEL\Anaconda3\envs\new_mtp\lib\site-packages\matplotlib\pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
districts.ST_NM.unique()
# Out:
# array(['Andhra Pradesh', 'Uttar Pradesh', 'Gujarat', 'Maharashtra',
#        'Mizoram', 'Rajasthan', 'Kerala', 'Madhya Pradesh', 'Uttarakhand',
#        'Haryana', 'Punjab', 'Jammu & Kashmir', 'Arunanchal Pradesh',
#        'Odisha', 'Bihar', 'Tamil Nadu', 'Karnataka', 'Assam',
#        'West Bengal', 'Chhattisgarh', 'Himachal Pradesh', 'Manipur',
#        'Jharkhand', 'NCT of Delhi', 'Chandigarh',
#        'Dadara & Nagar Havelli', 'Daman & Diu', 'Tripura', 'Nagaland',
#        'Sikkim', 'Meghalaya', 'Puducherry', 'Goa',
#        'Andaman & Nicobar Island', 'Lakshadweep'], dtype=object)
